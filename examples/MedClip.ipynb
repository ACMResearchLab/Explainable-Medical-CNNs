# %%
# !pip install git+https://github.com/RyanWangZf/MedCLIP.git


# !pip install medclip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/RyanWangZf/MedCLIP.git
#   Cloning https://github.com/RyanWangZf/MedCLIP.git to /tmp/pip-req-build-7bltx90q
#   Running command git clone --filter=blob:none --quiet https://github.com/RyanWangZf/MedCLIP.git /tmp/pip-req-build-7bltx90q
#   Resolved https://github.com/RyanWangZf/MedCLIP.git to commit 9c3396f20d5d54e4fae241b8cb06ca45848e98c9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from MedCLIP==0.0.3) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from MedCLIP==0.0.3) (1.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from MedCLIP==0.0.3) (8.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from MedCLIP==0.0.3) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from MedCLIP==0.0.3) (4.65.0)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk>=3.7 in /usr/local/lib/python3.10/dist-packages (from MedCLIP==0.0.3) (3.8.1)
# Requirement already satisfied: scikit_learn>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from MedCLIP==0.0.3) (1.2.2)
# Collecting textaugment>=1.3.4
#   Downloading textaugment-1.3.4-py3-none-any.whl (16 kB)
# Collecting timm>=0.6.11
#   Downloading timm-0.6.13-py3-none-any.whl (549 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from MedCLIP==0.0.3) (2.0.0+cu118)
# Requirement already satisfied: torchvision>=0.13.1 in /usr/local/lib/python3.10/dist-packages (from MedCLIP==0.0.3) (0.15.1+cu118)
# Collecting transformers<=4.24.0,>=4.23.1
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.7->MedCLIP==0.0.3) (2022.10.31)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.7->MedCLIP==0.0.3) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.7->MedCLIP==0.0.3) (8.1.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>=1.1.2->MedCLIP==0.0.3) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>=1.1.2->MedCLIP==0.0.3) (3.1.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from textaugment>=1.3.4->MedCLIP==0.0.3) (4.3.1)
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (from textaugment>=1.3.4->MedCLIP==0.0.3) (0.17.1)
# Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm>=0.6.11->MedCLIP==0.0.3) (6.0)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->MedCLIP==0.0.3) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->MedCLIP==0.0.3) (2.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->MedCLIP==0.0.3) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->MedCLIP==0.0.3) (1.11.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->MedCLIP==0.0.3) (4.5.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->MedCLIP==0.0.3) (3.1.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.12.1->MedCLIP==0.0.3) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.12.1->MedCLIP==0.0.3) (16.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.24.0,>=4.23.1->MedCLIP==0.0.3) (23.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 65.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->MedCLIP==0.0.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->MedCLIP==0.0.3) (2022.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->MedCLIP==0.0.3) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->MedCLIP==0.0.3) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->MedCLIP==0.0.3) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->MedCLIP==0.0.3) (2.0.12)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm>=0.6.11->MedCLIP==0.0.3) (2023.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->MedCLIP==0.0.3) (1.16.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->textaugment>=1.3.4->MedCLIP==0.0.3) (6.3.0)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.4 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.6 MB/s eta 0:00:00
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.1 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans->textaugment>=1.3.4->MedCLIP==0.0.3) (1.3.0)
# Collecting hstspreload
#   Downloading hstspreload-2023.1.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 41.3 MB/s eta 0:00:00
# Collecting chardet==3.*
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 6.6 MB/s eta 0:00:00
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 3.4 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.4 MB/s eta 0:00:00
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.1->MedCLIP==0.0.3) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12.1->MedCLIP==0.0.3) (1.3.0)
# Building wheels for collected packages: MedCLIP, wget, googletrans
#   Building wheel for MedCLIP (setup.py) ... done
#   Created wheel for MedCLIP: filename=MedCLIP-0.0.3-py3-none-any.whl size=28036 sha256=fb95c9e111757ec4077760ae68ff9d10ccc1261876c3d8285a7a8555553f15db
#   Stored in directory: /tmp/pip-ephem-wheel-cache-58n9a9ll/wheels/d5/ed/0c/c230538eb930e829193f90161c97b1781f48f07e2c7ea66053
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=0f77e1b73d54410d1ac8e7ae541b1a65be8e4a1f41c9ff6f22e5e981fbc0c620
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15735 sha256=bc80e3f48e1ec70d2f87192a9db1a51c8b7e37ce4e9d3a7081af42bc8a8cb4bb
#   Stored in directory: /root/.cache/pip/wheels/b3/81/ea/8b030407f8ebfc2f857814e086bb22ca2d4fea1a7be63652ab
# Successfully built MedCLIP wget googletrans
# Installing collected packages: wget, tokenizers, rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, huggingface-hub, httpx, transformers, googletrans, textaugment, timm, MedCLIP
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
# Successfully installed MedCLIP-0.0.3 chardet-3.0.4 googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2023.1.1 httpcore-0.9.1 httpx-0.13.3 huggingface-hub-0.14.1 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0 textaugment-1.3.4 timm-0.6.13 tokenizers-0.13.3 transformers-4.24.0 wget-3.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: medclip in /usr/local/lib/python3.10/dist-packages (0.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from medclip) (1.22.4)
# Requirement already satisfied: textaugment>=1.3.4 in /usr/local/lib/python3.10/dist-packages (from medclip) (1.3.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from medclip) (2.27.1)
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (from medclip) (3.2)
# Requirement already satisfied: scikit-learn>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from medclip) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from medclip) (1.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from medclip) (8.4.0)
# Requirement already satisfied: nltk>=3.7 in /usr/local/lib/python3.10/dist-packages (from medclip) (3.8.1)
# Requirement already satisfied: torch>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from medclip) (2.0.0+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from medclip) (4.65.0)
# Requirement already satisfied: transformers<=4.24.0,>=4.23.1 in /usr/local/lib/python3.10/dist-packages (from medclip) (4.24.0)
# Requirement already satisfied: timm>=0.6.11 in /usr/local/lib/python3.10/dist-packages (from medclip) (0.6.13)
# Requirement already satisfied: torchvision>=0.13.1 in /usr/local/lib/python3.10/dist-packages (from medclip) (0.15.1+cu118)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.7->medclip) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.7->medclip) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.7->medclip) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.2->medclip) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.2->medclip) (3.1.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from textaugment>=1.3.4->medclip) (4.3.1)
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (from textaugment>=1.3.4->medclip) (0.17.1)
# Requirement already satisfied: googletrans in /usr/local/lib/python3.10/dist-packages (from textaugment>=1.3.4->medclip) (3.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm>=0.6.11->medclip) (6.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm>=0.6.11->medclip) (0.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->medclip) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->medclip) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->medclip) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->medclip) (1.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->medclip) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.1->medclip) (4.5.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.12.1->medclip) (16.0.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.12.1->medclip) (3.25.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.24.0,>=4.23.1->medclip) (0.13.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<=4.24.0,>=4.23.1->medclip) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medclip) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medclip) (2022.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->medclip) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->medclip) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->medclip) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->medclip) (1.26.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm>=0.6.11->medclip) (2023.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->medclip) (1.16.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->textaugment>=1.3.4->medclip) (6.3.0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans->textaugment>=1.3.4->medclip) (0.13.3)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans->textaugment>=1.3.4->medclip) (1.5.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans->textaugment>=1.3.4->medclip) (1.3.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans->textaugment>=1.3.4->medclip) (0.9.1)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans->textaugment>=1.3.4->medclip) (2023.1.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans->textaugment>=1.3.4->medclip) (3.0.4)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans->textaugment>=1.3.4->medclip) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans->textaugment>=1.3.4->medclip) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans->textaugment>=1.3.4->medclip) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans->textaugment>=1.3.4->medclip) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.1->medclip) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12.1->medclip) (1.3.0)

# %%
from medclip import MedCLIPModel, MedCLIPVisionModelViT, MedCLIPVisionModel

# load MedCLIP-ResNet50
model = MedCLIPModel(vision_cls=MedCLIPVisionModel)
model.from_pretrained()

# load MedCLIP-ViT
model = MedCLIPModel(vision_cls=MedCLIPVisionModelViT)
model.from_pretrained()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 336MB/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
#  Download pretrained model from: https://storage.googleapis.com/pytrial/medclip-pretrained.zip
# load model weight from: ./pretrained/medclip-resnet
# Downloading (…)lve/main/config.json:   0%|          | 0.00/71.8k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/113M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Some weights of the model checkpoint at microsoft/swin-tiny-patch4-window7-224 were not used when initializing SwinModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing SwinModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing SwinModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#  Download pretrained model from: https://storage.googleapis.com/pytrial/medclip-vit-pretrained.zip
# load model weight from: ./pretrained/medclip-vit

# %%
from medclip import MedCLIPModel, MedCLIPVisionModelViT
from medclip import MedCLIPProcessor
from PIL import Image

from google.colab import drive
drive.mount('/content/drive')

# prepare for the demo image and texts
processor = MedCLIPProcessor()
image = Image.open('/content/drive/MyDrive/BloodImage_00387.jpg')
inputs = processor(
    text=["lungs remain severely hyperinflated with upper lobe emphysema", 
        "opacity left costophrenic angle is new since prior exam ___ represent some loculated fluid cavitation unlikely"], 
    images=image, 
    return_tensors="pt", 
    padding=True
    )

# pass to MedCLIP model
model = MedCLIPModel(vision_cls=MedCLIPVisionModelViT)
model.from_pretrained()
model.cuda()
outputs = model(**inputs)
print(outputs.keys())
# dict_keys(['img_embeds', 'text_embeds', 'logits', 'loss_value', 'logits_per_text'])
# Out:
# Mounted at /content/drive
# Some weights of the model checkpoint at microsoft/swin-tiny-patch4-window7-224 were not used when initializing SwinModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing SwinModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing SwinModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# load model weight from: ./pretrained/medclip-vit
# dict_keys(['img_embeds', 'text_embeds', 'logits', 'loss_value', 'logits_per_text'])

# %%
from medclip import MedCLIPModel, MedCLIPVisionModelViT
from medclip import MedCLIPProcessor
from medclip import PromptClassifier

processor = MedCLIPProcessor()
model = MedCLIPModel(vision_cls=MedCLIPVisionModelViT)
model.from_pretrained()
clf = PromptClassifier(model, ensemble=True)
clf.cuda()

# prepare input image
from PIL import Image
image = Image.open('/content/drive/MyDrive/BloodImage_00387.jpg')
inputs = processor(images=image, return_tensors="pt")

# prepare input prompt texts
from medclip.prompts import generate_chexpert_class_prompts, process_class_prompts
cls_prompts = process_class_prompts(generate_chexpert_class_prompts(n=10))
inputs['prompt_inputs'] = cls_prompts

# make classification
output = clf(**inputs)
print(output)
# {'logits': tensor([[0.5154, 0.4119, 0.2831, 0.2441, 0.4588]], device='cuda:0',
#       grad_fn=<StackBackward0>), 'class_names': ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema', 'Pleural Effusion']}
# Out:
# Some weights of the model checkpoint at microsoft/swin-tiny-patch4-window7-224 were not used when initializing SwinModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing SwinModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing SwinModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# load model weight from: ./pretrained/medclip-vit
# sample 10 num of prompts for Atelectasis from total 210
# sample 10 num of prompts for Cardiomegaly from total 15
# sample 10 num of prompts for Consolidation from total 192
# sample 10 num of prompts for Edema from total 18
# sample 10 num of prompts for Pleural Effusion from total 54
# {'logits': tensor([[0.6967, 0.5935, 0.2305, 0.5632, 1.0302]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'class_names': ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema', 'Pleural Effusion']}
